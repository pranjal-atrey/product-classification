# %%
# This code has been written by Pranjal Atrey
import pandas as pd
import os

os.chdir("..")

# %%
data = pd.read_csv('./data/altered_data_files/refactored_data_files/walmart_dataset.csv')

# Combined file
print("Combined: ")

unique_values_categories = data['category'].unique()
print("Number of categories: ",len(unique_values_categories))
print("List of unique categories: ",unique_values_categories) 

# Number of products
product_values = data['name']
print("Number of products: ",len(product_values))

# Number of unique products
unique_values = data['name'].unique()
print("Number of unique products: ",len(unique_values))

# Number of subcategories
unique_values = data['subcategory'].unique()
print("Number of subcategories: ",len(unique_values))

# %matplotlib inline
import matplotlib.pyplot as plt

pd.value_counts(data['category']).plot.bar()

plt.xlabel("Product Categories")
plt.ylabel("Number of Products")

plt.show()
# Out:
# Combined:
# Number of categories:  12
# List of unique categories:  ['Food' 'Health' 'Other' 'Sports & Outdoors' 'Baby' 'Home'
#  'Household Essentials' 'Clothing' 'Personal Care' 'Toys' 'Beauty'
#  'Premium Beauty']
# Number of products:  29983
# Number of unique products:  29681
# Number of subcategories:  919

# %%
data = pd.read_csv('./data/altered_data_files/refactored_data_files/amazon_dataset.csv')

# Combined file
print("Combined: ")

unique_values_categories = data['category'].unique()
print("Number of categories: ",len(unique_values_categories))
print("List of unique categories: ",unique_values_categories) 

# Number of products
product_values = data['name']
print("Number of products: ",len(product_values))

# Number of unique products
unique_values = data['name'].unique()
print("Number of unique products: ",len(unique_values))

# Number of subcategories
unique_values = data['subcategory'].unique()
print("Number of subcategories: ",len(unique_values))

# %matplotlib inline
import matplotlib.pyplot as plt

pd.value_counts(data['category']).plot.bar()

plt.xlabel("Product Categories")
plt.ylabel("Number of Products")

plt.show()
# Out:
# Combined:
# Number of categories:  13
# List of unique categories:  ['Hobbies' 'Characters & Brands' 'Fancy Dress' 'Other' 'Arts & Crafts'
#  'Games' 'Figures & Playsets' 'Sports Toys & Outdoor'
#  'Die-Cast & Toy Vehicles' 'Party Supplies' 'Dolls & Accessories'
#  'Puppets & Puppet Theatres' 'Jigsaws & Puzzles']
# Number of products:  9310
# Number of unique products:  9278
# Number of subcategories:  126

# %%
data = pd.read_csv('./data/altered_data_files/refactored_data_files/newchic_dataset.csv')

# Combined file
print("Combined: ")

unique_values_categories = data['category'].unique()
print("Number of categories: ",len(unique_values_categories))
print("List of unique categories: ",unique_values_categories) 

# Number of products
product_values = data['name']
print("Number of products: ",len(product_values))

# Number of unique products
unique_values = data['name'].unique()
print("Number of unique products: ",len(unique_values))

# Number of subcategories
unique_values = data['subcategory'].unique()
print("Number of subcategories: ",len(unique_values))

# %matplotlib inline
import matplotlib.pyplot as plt

pd.value_counts(data['category']).plot.bar()

plt.xlabel("Product Categories")
plt.ylabel("Number of Products")

plt.show()
# Out:
# Combined:
# Number of categories:  9
# List of unique categories:  ['accessories' 'bags' 'beauty' 'house' 'jewelry' 'kids' 'men' 'shoes'
#  'women']
# Number of products:  74999
# Number of unique products:  69395
# Number of subcategories:  651
